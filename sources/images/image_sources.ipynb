# %% [markdown]
# # Sources of the images used in this training material
#
#
# <center><img src="FAIR - forskningslivscyklussen.png" width="500" height="auto"><center>
# The research data life cycle. Source: DK Fair på tværs, licensed CC-BY-SA 4.0

# %% [markdown]
# <center><img src="FAIRness_figure.png" width="500" height="auto"><center>
# The FAIR guiding principles. Source: Svalbard Integrated Arctic Earth Observing System (SIOS), licensed CC BY 4.0

# %% [markdown]
# <center><img src="fair-vs-open.png" width="500" height="auto"><center>
# The difference between FAIR and Open Data. Source: FAIR vs open data. Image adapted from 'Open data, FAIR data and RDM: the ugly duckling' by S. Jones, licensed under CC BY.
