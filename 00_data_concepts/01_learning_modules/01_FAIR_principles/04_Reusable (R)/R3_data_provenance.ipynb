# %% [markdown]
# # (Meta)data should be associated with detailed provenance information (R3)
#
# sfsfs
#
# ---

# %%
Data AND metadata

# %% [markdown]
# _Source: [How to publish FAIR data (2024)](https://youtu.be/RC14Ty0D4w0?si=l9Ck1w1eaMpUeFtl)_
